# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop non-beneficial ID columns
application_df = application_df.drop(columns=['EIN', 'NAME', 'STATUS', 'SPECIAL_CONSIDERATIONS'])

# %%
# APPLICATION_TYPE value counts for binning
application_values = application_df['APPLICATION_TYPE'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_application = application_values[application_values < 1000].index.tolist()

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app, 'Other')

# %%
# CLASSIFICATION value counts for binning
classification_values = application_df['CLASSIFICATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_class = classification_values[classification_values < 1000].index.tolist()

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls, 'Other')

# %%
# ASK_AMT bins
ask_values_0 = application_df['ASK_AMT'][application_df['ASK_AMT'] == 5000]
ask_values_1 = application_df['ASK_AMT'][(application_df['ASK_AMT'] > 5000)]

# Replace in dataframe
for amt in ask_values_0:
    application_df.ASK_AMT = application_df.ASK_AMT.replace(amt, '5000')
for amt in ask_values_1:
    application_df.ASK_AMT = application_df.ASK_AMT.replace(amt, '>5000')

# %%
# AFFILIATION value counts for binning
affiliation_values = application_df['AFFILIATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_affiliation = affiliation_values[affiliation_values < 1000].index.tolist()

# Replace in dataframe
for aff in replace_affiliation:
    application_df.AFFILIATION = application_df.AFFILIATION.replace(aff, 'Other')

# %%
# ORGANIZATION value counts for binning
organization_values = application_df['ORGANIZATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_organization = organization_values[organization_values < 1000].index.tolist()

# Replace in dataframe
for org in replace_organization:
    application_df.ORGANIZATION = application_df.ORGANIZATION.replace(org, 'Other')

# %%
# Generate the categorical variable list
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# C:\Users\aayam\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(application_cat, 1)

# %%
# Split the preprocessed data into features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(['IS_SUCCESSFUL'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 120
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hiZdden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 120)               4200
#
#  dense_1 (Dense)             (None, 50)                6050
#
#  dense_2 (Dense)             (None, 18)                918
#
#  dense_3 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 11,187
# Trainable params: 11,187
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs('optimized_checkpoints/', exist_ok=True)
checkpoint_path = 'optimized_checkpoints/weights.{epoch:02d}.hdf5'

# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=4000)

# %%
# Train the model
fit_model = nn.fit(X_train, y_train, epochs=200, callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5991 - accuracy: 0.6974
# Epoch 2/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5736 - accuracy: 0.7213
# Epoch 3/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5685 - accuracy: 0.7255
# Epoch 4/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5661 - accuracy: 0.7273
# Epoch 5/200
# 764/804 [===========================>..] - ETA: 0s - loss: 0.5634 - accuracy: 0.7289
# Epoch 5: saving model to optimized_checkpoints\weights.05.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5632 - accuracy: 0.7292
# Epoch 6/200
# 804/804 [==============================] - 1s 899us/step - loss: 0.5613 - accuracy: 0.7283
# Epoch 7/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5609 - accuracy: 0.7301
# Epoch 8/200
# 804/804 [==============================] - 1s 958us/step - loss: 0.5603 - accuracy: 0.7293
# Epoch 9/200
# 804/804 [==============================] - 1s 939us/step - loss: 0.5586 - accuracy: 0.7314
# Epoch 10/200
# 727/804 [==========================>...] - ETA: 0s - loss: 0.5583 - accuracy: 0.7293
# Epoch 10: saving model to optimized_checkpoints\weights.10.hdf5
# 804/804 [==============================] - 1s 924us/step - loss: 0.5579 - accuracy: 0.7300
# Epoch 11/200
# 804/804 [==============================] - 1s 913us/step - loss: 0.5574 - accuracy: 0.7318
# Epoch 12/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5557 - accuracy: 0.7320
# Epoch 13/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5556 - accuracy: 0.7318
# Epoch 14/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5556 - accuracy: 0.7314
# Epoch 15/200
# 730/804 [==========================>...] - ETA: 0s - loss: 0.5549 - accuracy: 0.7327
# Epoch 15: saving model to optimized_checkpoints\weights.15.hdf5
# 804/804 [==============================] - 1s 985us/step - loss: 0.5551 - accuracy: 0.7320
# Epoch 16/200
# 804/804 [==============================] - 1s 997us/step - loss: 0.5554 - accuracy: 0.7318
# Epoch 17/200
# 804/804 [==============================] - 1s 982us/step - loss: 0.5542 - accuracy: 0.7319
# Epoch 18/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5539 - accuracy: 0.7334
# Epoch 19/200
# 804/804 [==============================] - 1s 993us/step - loss: 0.5539 - accuracy: 0.7333
# Epoch 20/200
# 698/804 [=========================>....] - ETA: 0s - loss: 0.5536 - accuracy: 0.7317
# Epoch 20: saving model to optimized_checkpoints\weights.20.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5533 - accuracy: 0.7326
# Epoch 21/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5533 - accuracy: 0.7321
# Epoch 22/200
# 804/804 [==============================] - 1s 963us/step - loss: 0.5533 - accuracy: 0.7329
# Epoch 23/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5529 - accuracy: 0.7331
# Epoch 24/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5528 - accuracy: 0.7319
# Epoch 25/200
# 671/804 [========================>.....] - ETA: 0s - loss: 0.5528 - accuracy: 0.7311
# Epoch 25: saving model to optimized_checkpoints\weights.25.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.7325
# Epoch 26/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5518 - accuracy: 0.7321
# Epoch 27/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5522 - accuracy: 0.7323
# Epoch 28/200
# 804/804 [==============================] - 1s 997us/step - loss: 0.5518 - accuracy: 0.7332
# Epoch 29/200
# 804/804 [==============================] - 1s 991us/step - loss: 0.5516 - accuracy: 0.7320
# Epoch 30/200
# 681/804 [========================>.....] - ETA: 0s - loss: 0.5511 - accuracy: 0.7337
# Epoch 30: saving model to optimized_checkpoints\weights.30.hdf5
# 804/804 [==============================] - 1s 984us/step - loss: 0.5514 - accuracy: 0.7332
# Epoch 31/200
# 804/804 [==============================] - 1s 975us/step - loss: 0.5514 - accuracy: 0.7327
# Epoch 32/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7332
# Epoch 33/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5507 - accuracy: 0.7330
# Epoch 34/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5510 - accuracy: 0.7341
# Epoch 35/200
# 658/804 [=======================>......] - ETA: 0s - loss: 0.5515 - accuracy: 0.7335
# Epoch 35: saving model to optimized_checkpoints\weights.35.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5510 - accuracy: 0.7336
# Epoch 36/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7341
# Epoch 37/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5500 - accuracy: 0.7338
# Epoch 38/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.7337
# Epoch 39/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5498 - accuracy: 0.7344
# Epoch 40/200
# 613/804 [=====================>........] - ETA: 0s - loss: 0.5463 - accuracy: 0.7357
# Epoch 40: saving model to optimized_checkpoints\weights.40.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5498 - accuracy: 0.7327
# Epoch 41/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.7336
# Epoch 42/200
# 804/804 [==============================] - 1s 975us/step - loss: 0.5494 - accuracy: 0.7341
# Epoch 43/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.7339
# Epoch 44/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7336
# Epoch 45/200
# 600/804 [=====================>........] - ETA: 0s - loss: 0.5473 - accuracy: 0.7348
# Epoch 45: saving model to optimized_checkpoints\weights.45.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5494 - accuracy: 0.
# 804/804 [==============================] - 1s 971us/step - loss: 0.5433 - accuracy: 0.7372
# Epoch 98/200
# 804/804 [==============================] - 1s 966us/step - loss: 0.5432 - accuracy: 0.7367
# Epoch 99/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5432 - accuracy: 0.7374
# Epoch 100/200
# 362/804 [============>.................] - ETA: 0s - loss: 0.5413 - accuracy: 0.7395
# Epoch 100: saving model to optimized_checkpoints\weights.100.hdf5
# 804/804 [==============================] - 1s 988us/step - loss: 0.5435 - accuracy: 0.7373
# Epoch 101/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7374
# Epoch 102/200
# 804/804 [==============================] - 1s 944us/step - loss: 0.5432 - accuracy: 0.7369
# Epoch 103/200
# 804/804 [==============================] - 1s 938us/step - loss: 0.5429 - accuracy: 0.7369
# Epoch 104/200
# 804/804 [==============================] - 1s 956us/step - loss: 0.5427 - accuracy: 0.7369
# Epoch 105/200
# 369/804 [============>.................] - ETA: 0s - loss: 0.5439 - accuracy: 0.7385
# Epoch 105: saving model to optimized_checkpoints\weights.105.hdf5
# 804/804 [==============================] - 1s 978us/step - loss: 0.5430 - accuracy: 0.7376
# Epoch 106/200
# 804/804 [==============================] - 1s 976us/step - loss: 0.5423 - accuracy: 0.7378
# Epoch 107/200
# 804/804 [==============================] - 1s 980us/step - loss: 0.5428 - accuracy: 0.7375
# Epoch 108/200
# 804/804 [==============================] - 1s 990us/step - loss: 0.5424 - accuracy: 0.7375
# Epoch 109/200
# 804/804 [==============================] - 1s 966us/step - loss: 0.5424 - accuracy: 0.7381
# Epoch 110/200
# 312/804 [==========>...................] - ETA: 0s - loss: 0.5370 - accuracy: 0.7413
# Epoch 110: saving model to optimized_checkpoints\weights.110.hdf5
# 804/804 [==============================] - 1s 972us/step - loss: 0.5423 - accuracy: 0.7373
# Epoch 111/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7376
# Epoch 112/200
# 804/804 [==============================] - 1s 879us/step - loss: 0.5421 - accuracy: 0.7377
# Epoch 113/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5424 - accuracy: 0.7376
# Epoch 114/200
# 804/804 [==============================] - 1s 998us/step - loss: 0.5421 - accuracy: 0.7378
# Epoch 115/200
# 308/804 [==========>...................] - ETA: 0s - loss: 0.5426 - accuracy: 0.7378
# Epoch 115: saving model to optimized_checkpoints\weights.115.hdf5
# 804/804 [==============================] - 1s 995us/step - loss: 0.5420 - accuracy: 0.7386
# Epoch 116/200
# 804/804 [==============================] - 1s 994us/step - loss: 0.5417 - accuracy: 0.7381
# Epoch 117/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7380
# Epoch 118/200
# 804/804 [==============================] - 1s 988us/step - loss: 0.5420 - accuracy: 0.7378
# Epoch 119/200
# 804/804 [==============================] - 1s 994us/step - loss: 0.5415 - accuracy: 0.7384
# Epoch 120/200
# 309/804 [==========>...................] - ETA: 0s - loss: 0.5388 - accuracy: 0.7398
# Epoch 120: saving model to optimized_checkpoints\weights.120.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7387
# Epoch 121/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7387
# Epoch 122/200
# 804/804 [==============================] - 1s 966us/step - loss: 0.5414 - accuracy: 0.7380
# Epoch 123/200
# 804/804 [==============================] - 1s 974us/step - loss: 0.5415 - accuracy: 0.7388
# Epoch 124/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5414 - accuracy: 0.7384
# Epoch 125/200
# 263/804 [========>.....................] - ETA: 0s - loss: 0.5399 - accuracy: 0.7403
# Epoch 125: saving model to optimized_checkpoints\weights.125.hdf5
# 804/804 [==============================] - 1s 968us/step - loss: 0.5413 - accuracy: 0.7386
# Epoch 126/200
# 804/804 [==============================] - 1s 976us/step - loss: 0.5413 - accuracy: 0.7383
# Epoch 127/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5410 - accuracy: 0.7383
# Epoch 128/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5410 - accuracy: 0.7383
# Epoch 129/200
# 804/804 [==============================] - 1s 965us/step - loss: 0.5407 - accuracy: 0.7383
# Epoch 130/200
# 261/804 [========>.....................] - ETA: 0s - loss: 0.5412 - accuracy: 0.7348
# Epoch 130: saving model to optimized_checkpoints\weights.130.hdf5
# 804/804 [==============================] - 1s 987us/step - loss: 0.5407 - accuracy: 0.7381
# Epoch 131/200
# 804/804 [==============================] - 1s 999us/step - loss: 0.5408 - accuracy: 0.7380
# Epoch 132/200
# 804/804 [==============================] - 1s 853us/step - loss: 0.5406 - accuracy: 0.7391
# Epoch 133/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7395
# Epoch 134/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7381
# Epoch 135/200
# 251/804 [========>.....................] - ETA: 0s - loss: 0.5423 - accuracy: 0.7372
# Epoch 135: saving model to optimized_checkpoints\weights.135.hdf5
# 804/804 [==============================] - 1s 964us/step - loss: 0.5405 - accuracy: 0.7389
# Epoch 136/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 137/200
# 804/804 [==============================] - 1s 936us/step - loss: 0.5408 - accuracy: 0.7396
# Epoch 138/200
# 804/804 [==============================] - 1s 936us/step - loss: 0.5403 - accuracy: 0.7393
# Epoch 139/200
# 804/804 [==============================] - 1s 983us/step - loss: 0.5404 - accuracy: 0.7391
# Epoch 140/200
# 240/804 [=======>......................] - ETA: 0s - loss: 0.5426 - accuracy: 0.7389
# Epoch 140: saving model to optimized_checkpoints\weights.140.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7392
# Epoch 141/200
# 804/804 [==============================] - 1s 992us/step - loss: 0.5403 - accuracy: 0.7391
# Epoch 142/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7394
# Epoch 143/200
# 804/804 [==============================] - 1s 926us/step - loss: 0.5403 - accuracy: 0.7389
# Epoch 144/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5399 - accuracy: 0.7392
# Epoch 145/200
# 179/804 [=====>........................] - ETA: 0s - loss: 0.5321 - accuracy: 0.7446
# Epoch 145: saving model to optimized_checkpoints\weights.145.hdf5
# 804/804 [==============================] - 1s 915us/step - loss: 0.5403 - accuracy: 0.7386
# Epoch 146/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5399 - accuracy: 0.7392
# Epoch 147/200
# 804/804 [==============================] - 1s 961us/step - loss: 0.5402 - accuracy: 0.7391
# Epoch 148/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5396 - accuracy: 0.7399
# Epoch 149/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5396 - accuracy: 0.7386
# Epoch 150/200
# 153/804 [====>.........................] - ETA: 0s - loss: 0.5438 - accuracy: 0.7404
# Epoch 150: saving model to optimized_checkpoints\weights.150.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7399
# Epoch 151/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5394 - accuracy: 0.7401
# Epoch 152/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5397 - accuracy: 0.7398
# Epoch 153/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5397 - accuracy: 0.7395
# Epoch 154/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5393 - accuracy: 0.7392
# Epoch 155/200
# 158/804 [====>.........................] - ETA: 0s - loss: 0.5351 - accuracy: 0.7466
# Epoch 155: saving model to optimized_checkpoints\weights.155.hdf5
# 804/804 [==============================] - 1s 971us/step - loss: 0.5395 - accuracy: 0.7396
# Epoch 156/200
# 804/804 [==============================] - 1s 985us/step - loss: 0.5397 - accuracy: 0.7391
# Epoch 157/200
# 804/804 [==============================] - 1s 978us/step - loss: 0.5396 - accuracy: 0.7397
# Epoch 158/200
# 804/804 [==============================] - 1s 978us/step - loss: 0.5394 - accuracy: 0.7392
# Epoch 159/200
# 804/804 [==============================] - 1s 982us/step - loss: 0.5393 - accuracy: 0.7396
# Epoch 160/200
# 152/804 [====>.........................] - ETA: 0s - loss: 0.5470 - accuracy: 0.7296
# Epoch 160: saving model to optimized_checkpoints\weights.160.hdf5
# 804/804 [==============================] - 1s 979us/step - loss: 0.5391 - accuracy: 0.7394
# Epoch 161/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7389
# Epoch 162/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7402
# Epoch 163/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5391 - accuracy: 0.7399
# Epoch 164/200
# 804/804 [==============================] - 1s 970us/step - loss: 0.5395 - accuracy: 0.7397
# Epoch 165/200
# 104/804 [==>...........................] - ETA: 0s - loss: 0.5449 - accuracy: 0.7323
# Epoch 165: saving model to optimized_checkpoints\weights.165.hdf5
# 804/804 [==============================] - 1s 998us/step - loss: 0.5390 - accuracy: 0.7400
# Epoch 166/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5390 - accuracy: 0.7399
# Epoch 167/200
# 804/804 [==============================] - 1s 963us/step - loss: 0.5390 - accuracy: 0.7392
# Epoch 168/200
# 804/804 [==============================] - 1s 975us/step - loss: 0.5389 - accuracy: 0.7395
# Epoch 169/200
# 804/804 [==============================] - 1s 977us/step - loss: 0.5388 - accuracy: 0.7402
# Epoch 170/200
# 101/804 [==>...........................] - ETA: 0s - loss: 0.5300 - accuracy: 0.7457
# Epoch 170: saving model to optimized_checkpoints\weights.170.hdf5
# 804/804 [==============================] - 1s 993us/step - loss: 0.5387 - accuracy: 0.7399
# Epoch 171/200
# 804/804 [==============================] - 1s 984us/step - loss: 0.5390 - accuracy: 0.7402
# Epoch 172/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5386 - accuracy: 0.7405
# Epoch 173/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5390 - accuracy: 0.7404
# Epoch 174/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5384 - accuracy: 0.7400
# Epoch 175/200
# 101/804 [==>...........................] - ETA: 0s - loss: 0.5271 - accuracy: 0.7512
# Epoch 175: saving model to optimized_checkpoints\weights.175.hdf5
# 804/804 [==============================] - 1s 981us/step - loss: 0.5386 - accuracy: 0.7405
# Epoch 176/200
# 804/804 [==============================] - 1s 969us/step - loss: 0.5387 - accuracy: 0.7403
# Epoch 177/200
# 804/804 [==============================] - 1s 976us/step - loss: 0.5386 - accuracy: 0.7406
# Epoch 178/200
# 804/804 [==============================] - 1s 963us/step - loss: 0.5384 - accuracy: 0.7409
# Epoch 179/200
# 804/804 [==============================] - 1s 966us/step - loss: 0.5385 - accuracy: 0.7402
# Epoch 180/200
#  52/804 [>.............................] - ETA: 0s - loss: 0.5522 - accuracy: 0.7356
# Epoch 180: saving model to optimized_checkpoints\weights.180.hdf5
# 804/804 [==============================] - 1s 984us/step - loss: 0.5384 - accuracy: 0.7405
# Epoch 181/200
# 804/804 [==============================] - 1s 966us/step - loss: 0.5386 - accuracy: 0.7409
# Epoch 182/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7404
# Epoch 183/200
# 804/804 [==============================] - 1s 982us/step - loss: 0.5383 - accuracy: 0.7403
# Epoch 184/200
# 804/804 [==============================] - 1s 972us/step - loss: 0.5387 - accuracy: 0.7406
# Epoch 185/200
#  49/804 [>.............................] - ETA: 0s - loss: 0.5289 - accuracy: 0.7577
# Epoch 185: saving model to optimized_checkpoints\weights.185.hdf5
# 804/804 [==============================] - 1s 981us/step - loss: 0.5382 - accuracy: 0.7410
# Epoch 186/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5380 - accuracy: 0.7408
# Epoch 187/200
# 804/804 [==============================] - 1s 962us/step - loss: 0.5379 - accuracy: 0.7409
# Epoch 188/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5381 - accuracy: 0.7407
# Epoch 189/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5381 - accuracy: 0.7398
# Epoch 190/200
#   1/804 [..............................] - ETA: 1s - loss: 0.3811 - accuracy: 0.9062
# Epoch 190: saving model to optimized_checkpoints\weights.190.hdf5
# 804/804 [==============================] - 1s 988us/step - loss: 0.5378 - accuracy: 0.7405
# Epoch 191/200
# 804/804 [==============================] - 1s 963us/step - loss: 0.5379 - accuracy: 0.7403
# Epoch 192/200
# 804/804 [==============================] - 1s 968us/step - loss: 0.5380 - accuracy: 0.7401
# Epoch 193/200
# 804/804 [==============================] - 1s 971us/step - loss: 0.5376 - accuracy: 0.7410
# Epoch 194/200
# 804/804 [==============================] - 1s 978us/step - loss: 0.5378 - accuracy: 0.7409
# Epoch 195/200
#   1/804 [..............................] - ETA: 1s - loss: 0.5468 - accuracy: 0.7500
# Epoch 195: saving model to optimized_checkpoints\weights.195.hdf5
# 804/804 [==============================] - 1s 975us/step - loss: 0.5379 - accuracy: 0.7409
# Epoch 196/200
# 804/804 [==============================] - 1s 979us/step - loss: 0.5376 - accuracy: 0.7409
# Epoch 197/200
# 804/804 [==============================] - 1s 973us/step - loss: 0.5377 - accuracy: 0.7404
# Epoch 198/200
# 804/804 [==============================] - 1s 986us/step - loss: 0.5375 - accuracy: 0.7407
# Epoch 199/200
# 804/804 [==============================] - 1s 965us/step - loss: 0.5378 - accuracy: 0.7403
# Epoch 200/200
#   1/804 [..............................] - ETA: 0s - loss: 0.6348 - accuracy: 0.6562
# Epoch 200: saving model to optimized_checkpoints\weights.200.hdf5
# 804/804 [==============================] - 1s 989us/step - loss: 0.5376 - accuracy: 0.7409

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 268/268 - 0s - loss: 1.3911 - accuracy: 0.6617 - 267ms/epoch - 994us/step
# Loss: 1.3911465406417847, Accuracy: 0.6616909503936768

# %%
# Export the model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')
